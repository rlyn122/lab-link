# %%
import pandas as pd
from scholarly import scholarly
from scholarly import ProxyGenerator
import os
import csv

# %%
# setup free proxy, lowkey doesn't work very well so I suggest using ScraperAPI
# you can just keep getting free trials froms ScraperAPI lmao
pg = ProxyGenerator()
pg.FreeProxies()
scholarly.use_proxy(pg)

# %%
# how to set up ScraperAPI proxy, use the key that it gives u when u sign up
pg = ProxyGenerator()
success = pg.ScraperAPI('684fcce481732da87c4fc9d70d543e72')
scholarly.use_proxy(pg)
# Out:
# ScraperAPI account limit reached.

# %%
# list of professors to scrape, will probably add their scholar profile id bc its easier to find them
QTM_professors1 = [
    'zvOPm8gAAAAJ', # Weihua An
    'U_xI7eAAAAAJ', # Michal Arbilly
    '9zsMl5kAAAAJ', # Hun Chung
    'LB9hecMAAAAJ', # Jacopo Di Iorio
    '9s1slLcAAAAJ', # Danilo Freire
    '30u0V1EAAAAJ', # Adam Glynn
    'JnRNZccAAAAJ', # Jo Guldi
    'lTDtAqoAAAAJ', # Craig Hadley
    '_QUUb-gAAAAJ', # David Hirshberg
    'Xc9Sco0AAAAJ', # Lauren Klein
    'Q5KlCMwAAAAJ' # Kevin McAlister
]

QTM_professors2 = [
    'dk_JiwgAAAAJ', # Pablo Montagnes
    'rhSQ6egAAAAJ', # Gregory Palermo
    'zEq533oAAAAJ', # John Patty
    'XD8LHcgAAAAJ', # Kevin Quinn
    'yFPu-mkAAAAJ', # Alejandro Sanchez Becerra
    '_OzUlMkAAAAJ', # Sandeep Soni
    'J4NQQIEAAAAJ', # Allison Stashko
    'vgfVoq4AAAAJ', # Joseph Sutherland
    'OGjoFXcAAAAJ', # Alexander Tolbert
    'lg_0u-0AAAAJ' # Ruoxuan Xiong
]

# %%
CS_professors1 = [
    '3BX3vWcAAAAJ', # Eugene Agichtein
    '2jEFz5EAAAAJ', # Dorian Arnold
    'aL6XtIUAAAAJ', # Yana Bromberg
    'xdddblAAAAAJ', # Jinho Choi
    'AIf9mB4AAAAJ', # Nosayba El-Sayed
    'EQ61oMAAAAAJ', # Davide Fossati
    'BOFfWR0AAAAJ', # Zhichun Guo
    'DrUBb5sAAAAJ', # Joyce Ho
    'eWow24EAAAAJ', # Wei Jin
    'cAE-vgwAAAAJ' # Joonseok Kim
]

CS_professors2 = [
    '22ohn6AAAAAJ', # Fei Liu
    'RxcQjoYAAAAJ', # Yolanda Rankin
    '-6bAV2cAAAAJ', # Kai Shu
    'a_z5a5wAAAAJ', # Shengpu Tang
    'YfcphqMAAAAJ', # Emily Wall
    'yGtJEDsAAAAJ', # Kristin Williams
    'jJ8BLgsAAAAJ', # Li Xiong
    'mOINlwcAAAAJ', # Carl Yang
    'qnvyqtwAAAAJ', # Liang Zhao
    's-FDyf4AAAAJ' # Andreas Zufle
]

# %%
# getting the author profile from id (Weihua An)
author = scholarly.search_author_id('zvOPm8gAAAAJ')

# %%
# Fill the author object with the authors publications
author = scholarly.fill(author, sections=['publications'])
scholarly.pprint(author)
# Out:
# b'{\'affiliation\': \'Emory University, Sociology & Quantitative Theory and Methods\',\n \'citedby\': 1304,\n \'email_domain\': \'@emory.edu\',\n \'filled\': False,\n \'homepage\': \'http://weihuaan.net/\',\n \'interests\': [\'Social Networks\',\n               \'Causal Inference\',\n               \'Social Policy\',\n               \'Health\',\n               \'Organizations\'],\n \'name\': \'Weihua An\',\n \'organization\': 7693822459085397235,\n \'publications\': [{\'author_pub_id\': \'zvOPm8gAAAAJ:d1gkVwhDpl0C\',\n                   \'bib\': {\'citation\': \'Social forces 92 (1), 303-327, 2013\',\n                           \'pub_year\': \'2013\',\n                           \'title\': \'Evicting Children\'},\n                   \'citedby_url\': \'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=2730129611184238020\',\n                   \'cites_id\': [\'2730129611184238020\'],\n                   \'filled\': False,\n                   \'num_citations\': 203,\n                   \'source\': \'AUTHOR_PUBLICATION_ENTRY\'},\n                  {\'author_pub_id\': \'zvOPm8gAAAAJ:2osOgNQ5qMEC\',\n                   \'bib\': {\'citation\': \'Handbook of causal analysis for social \'\n                                       \'research, 353-374, 2013\',\n                           \'pub_year\': \'2013\',\n                           \'title\': \'Social networks and causal inference\'},\n                   \'citedby_url\': \'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8024766442895079106\',\n                   \'cites_id\': [\'8024766442895079106\'],\n                   \'filled\': False,\n                   \'num_citations\': 124,\n                   \'source\': \'AUTHOR_PUBLICATION_ENTRY\'},\n                  {\'author_pub_id\': \'zvOPm8gAAAAJ:u-x6o8ySG0sC\',\n                   \'bib\': {\'citation\': \'Sociological Methodology 40 (1), \'\n                                       \'151-189, 2010\',\n                           \'pub_year\': \'2010\',\n                           \'title\': \'Bayesian Propensity Score Estimators: \'\n                                    \'Incorporating Uncertainties in Propensity \'\n                                    \'Scores into Causal Inference\'},\n                   \'citedby_url\': \'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1653872042154252890\',\n                   \'cites_id\': [\'1653872042154252890\'],\n                   \'filled\': False,\n                   \'num_citations\': 95,\n                   \'source\': \'AUTHOR_PUBLICATION_ENTRY\'},\n                  {\'author_pub_id\': \'zvOPm8gAAAAJ:u5HHmVD_uO8C\',\n                   \'bib\': {\'citation\': \'The SAGE handbook of social network \'\n                                       \'analysis, 514-532, 2014\',\n                           \'pub_year\': \'2014\',\n                           \'title\': \'Models and methods to identify peer \'\n                                    \'effects\'},\n                   \'citedby_url\': \'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1668891974076748550\',\n                   \'cites_id\': [\'1668891974076748550\'],\n                   \'filled\': False,\n                   \'num_citations\': 92,\n                   \'source\': \'AUTHOR_PUBLICATION_ENTRY\'},\n                  {\'author_pub_id\': \'zvOPm8gAAAAJ:1Ye0OR6EYb4C\',\n                   \'bib\': {\'citation\': \'Social science research 81, 192-208, \'\n                                       \'2019\',\n                           \'pub_year\': \'2019\',\n                           \'title\': \'Social capital in the creation of \'\n                                    \'cultural capital: Family structure, \'\n                                    \'neighborhood cohesion, and \'\n                                    \'extracurricular participation\'},\n                   \'citedby_url\': \'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4056377210864685989\',\n                   \'cites_id\': [\'4056 ...

# %%
# filter out the publications that are older than 2020 before filling
filtered_publications = [
    pub for pub in author.get('publications', [])
    if int(pub.get('bib', {}).get('pub_year', 0)) >= 2020]

print(filtered_publications)
# Out:
# [{'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Causal network analysis', 'pub_year': '2022', 'citation': 'Annual Review of Sociology 48 (1), 23-41, 2022'}, 'filled': False, 'author_pub_id': 'zvOPm8gAAAAJ:-jrNzM816MMC', 'num_citations': 35, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13437606084044806831', 'cites_id': ['13437606084044806831']}, {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Friendship network formation in Chinese middle schools: Patterns of inequality and homophily', 'pub_year': '2022', 'citation': 'Social Networks 68, 218-228, 2022'}, 'filled': False, 'author_pub_id': 'zvOPm8gAAAAJ:MAUkC_7iAq8C', 'num_citations': 20, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13873405708389654494', 'cites_id': ['13873405708389654494']}, {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'You said, they said: A framework on informant accuracy with application to studying self-reports and peer-reports', 'pub_year': '2022', 'citation': 'Social Networks 70, 187-197, 2022'}, 'filled': False, 'author_pub_id': 'zvOPm8gAAAAJ:QyXJ3EUuO1IC', 'num_citations': 18, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=165347335486856994', 'cites_id': ['165347335486856994']}, {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Opening the blackbox of treatment interference: Tracing treatment diffusion through network analysis', 'pub_year': '2022', 'citation': 'Sociological Methods & Research 51 (1), 141-164, 2022'}, 'filled': False, 'author_pub_id': 'zvOPm8gAAAAJ:-7ulzOJl1JYC', 'num_citations': 15, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=18309051332168774395', 'cites_id': ['18309051332168774395']}, {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Methodological advances in quantitative social science: In celebration of the Social Science Research 50th anniversary', 'pub_year': '2023', 'citation': 'Social science research 110, 102843, 2023'}, 'filled': False, 'author_pub_id': 'zvOPm8gAAAAJ:ce2CqMG-AY4C', 'num_citations': 11, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=6253633600698195887', 'cites_id': ['6253633600698195887']}, {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Fear not scarcity but inequality, not poverty but instability', 'pub_year': '2021', 'citation': 'Sociological Methods & Research 50 (3), 939-943, 2021'}, 'filled': False, 'author_pub_id': 'zvOPm8gAAAAJ:Dem6FJhTUoYC', 'num_citations': 5, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=17344691773977190415', 'cites_id': ['17344691773977190415']}, {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'A tale of twin dependence: a new multivariate regression model and an FGLS estimator for analyzing outcomes with network dependence', 'pub_year': '2023', 'citation': 'Sociological Methods & Research 52 (4), 1947-1980, 2023'}, 'filled': False, 'author_pub_id': 'zvOPm8gAAAAJ:HGTzPopzzJcC', 'num_citations': 4, 'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13425663947034887224', 'cites_id': ['13425663947034887224']}, {'container_type': 'Publication', 'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>, 'bib': {'title': 'Characterization of trajectories of physical activity and cigarette smoking from early adolescence to adulthood', 'pub_year': '2023', 'citation': 'BMC Public Health 23  ...

# %%
publication_data = []
# loops through each filtered publication and fills it with the required information 
# (takes a while depending on how many papers)
for pub in filtered_publications:
    try:
        filled_pub = scholarly.fill(pub)
        bib = filled_pub.get('bib', {})
        title = bib.get('title', '')
        year = bib.get('pub_year', '')
        abstract = bib.get('abstract', '')
        url = filled_pub.get('pub_url', '')

        publication_data.append({
            'Author': author.get('name', ''),
            'Title': title,
            'Year': year,
            'URL': url,
            'Abstract': abstract
        })
    except Exception as e:
        print(f"Error filling publication: {e}")

publications_df = pd.DataFrame(publication_data)

# df that has the publications of the author
display(publications_df)

# %%
# DONT USE LMAO
def scrape_recent_publications(professor_ids):
    all_publications = []
    for prof_id in professor_ids:
        try:
            print(f"Fetching author: {prof_id}")
            author = scholarly.search_author_id(prof_id)
            author = scholarly.fill(author, sections=['publications'])
            name = author.get('name', 'Unknown')

            filtered_pubs = [
                pub for pub in author.get('publications', [])
                if int(pub.get('bib', {}).get('pub_year', 0)) >= 2020
            ]

            for pub in filtered_pubs:
                try:
                    filled_pub = scholarly.fill(pub)
                    bib = filled_pub.get('bib', {})
                    all_publications.append({
                        'Author': name,
                        'Title': bib.get('title', ''),
                        'Year': bib.get('pub_year', ''),
                        'URL': filled_pub.get('pub_url', ''),
                        'Abstract': bib.get('abstract', '')
                    })
                except Exception as e:
                    print(f"Error filling publication for {name}: {e}")
        except Exception as e:
            print(f"Error fetching author with ID {prof_id}: {e}")

    return pd.DataFrame(all_publications)

# %%
def scrape_professors_to_csv(professor_ids, start_year=2020, csv_file='publications.csv', log_file='processed_ids.txt'):
    # Create CSV file with headers if it doesn't exist
    if not os.path.exists(csv_file):
        with open(csv_file, mode='w', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=['Author', 'Title', 'Year', 'URL', 'Abstract'])
            writer.writeheader()

    # Load processed IDs to avoid re-processing
    processed_ids = set()
    if os.path.exists(log_file):
        with open(log_file, 'r') as f:
            processed_ids = set(line.strip() for line in f.readlines())

    for prof_id in professor_ids:
        if prof_id in processed_ids:
            print(f"Skipping already processed ID: {prof_id}")
            continue

        try:
            print(f"Fetching author: {prof_id}")
            author = scholarly.search_author_id(prof_id)
            author = scholarly.fill(author, sections=['publications'])
            publications = author.get('publications', [])

            filtered_publications = [
                pub for pub in publications
                if int(pub.get('bib', {}).get('pub_year', 0)) >= start_year
            ]

            with open(csv_file, mode='a', newline='', encoding='utf-8') as f:
                writer = csv.DictWriter(f, fieldnames=['Author', 'Title', 'Year', 'URL', 'Abstract'])

                for pub in filtered_publications:
                    try:
                        filled_pub = scholarly.fill(pub)
                        bib = filled_pub.get('bib', {})
                        writer.writerow({
                            'Author': author.get('name', ''),
                            'Title': bib.get('title', ''),
                            'Year': bib.get('pub_year', ''),
                            'URL': filled_pub.get('pub_url', ''),
                            'Abstract': bib.get('abstract', '')
                        })
                    except Exception as e:
                        print(f"[{author.get('name', 'Unknown')}]: Error filling publication: {e}")

            # Append processed ID to the log
            with open(log_file, 'a') as log_f:
                log_f.write(f"{prof_id}\n")

        except Exception as e:
            print(f"Error processing author ID {prof_id}: {e}")

# %%
# Run this to scrape QTM professors
scrape_professors_to_csv(QTM_professors2, csv_file='QTM_publications.csv')
# Out:
# Skipping already processed ID: dk_JiwgAAAAJ
# Skipping already processed ID: rhSQ6egAAAAJ
# Skipping already processed ID: zEq533oAAAAJ
# Fetching author: XD8LHcgAAAAJ
# Fetching author: yFPu-mkAAAAJ
# Fetching author: _OzUlMkAAAAJ
# Fetching author: J4NQQIEAAAAJ
# Fetching author: vgfVoq4AAAAJ
# Fetching author: OGjoFXcAAAAJ
# Fetching author: lg_0u-0AAAAJ

# %%
# Display the QTM df
publications_df = pd.read_csv('QTM_publications.csv')
display(publications_df)
# Out:
#        Author                                              Title  Year  \
# 0   Weihua An                            Causal network analysis  2022
# 1   Weihua An  Friendship network formation in Chinese middle...  2022
# 2   Weihua An  You said, they said: A framework on informant ...  2022
# 3   Weihua An  Opening the blackbox of treatment interference...  2022
# 4   Weihua An  Methodological advances in quantitative social...  2023
# 5   Weihua An  Fear not scarcity but inequality, not poverty ...  2021
# 6   Weihua An  A tale of twin dependence: a new multivariate ...  2023
# 7   Weihua An  Characterization of trajectories of physical a...  2023
# 8   Weihua An  Race, state surveillance, and policy spillover...  2023
# 9   Weihua An  The nearness between us, and the space within ...  2020
# 10  Weihua An  Testing a Population-Based Outreach Interventi...  2024
# 11  Weihua An  Comparing Egocentric and Sociocentric Centrali...  2024
# 12  Weihua An  Developing and assessing a kin keeping scale w...  2023
#
#                                                   URL  \
# 0   https://www.annualreviews.org/content/journals...
# 1   https://www.sciencedirect.com/science/article/...
# 2   https://www.sciencedirect.com/science/article/...
# 3   https://journals.sagepub.com/doi/abs/10.1177/0...
# 4           https://pubmed.ncbi.nlm.nih.gov/36797000/
# 5   https://journals.sagepub.com/doi/abs/10.1177/0...
# 6   https://journals.sagepub.com/doi/abs/10.1177/0...
# 7   https://link.springer.com/article/10.1186/s128...
# 8   https://academic.oup.com/sf/article-abstract/1...
# 9   https://journals.sagepub.com/doi/abs/10.1177/0...
# 10  https://aacrjournals.org/cebp/article/33/9/118...
# 11  https://journals.sagepub.com/doi/abs/10.1177/0...
# 12  https://link.springer.com/article/10.1007/s126...
#
#                                              Abstract
# 0   Fueled by recent advances in statistical model...
# 1   Previous studies on adolescent friendship netw...
# 2   Informants have been used extensively to provi...
# 3   Causal inference under treatment interference ...
# 4   Methodological advances in quantitative social...
# 5   This special issue, “New Quantitative Approach...
# 6   In this article, I present a new multivariate ...
# 7   Cigarette smoking and physical inactivity are ...
# 8   This paper investigates whether restrictive im...
# 9   The year 2020 has been unprecedented. As a res...
# 10  Most relatives of women with ovarian cancer ar...
# 11  Egocentric networks represent a popular resear...
# 12  Promoting family communication about inherited...

# %%
# Run this to scrape the CS professors
# two sets of professors because I was too lazy to combine them into one list lol just change 1 to 2 to scrape the other set
scrape_professors_to_csv(CS_professors2, csv_file='CS_publications.csv')
# Out:
# Fetching author: 22ohn6AAAAAJ
# Fetching author: RxcQjoYAAAAJ
# Fetching author: -6bAV2cAAAAJ
# Fetching author: a_z5a5wAAAAJ
# Fetching author: YfcphqMAAAAJ
# Fetching author: yGtJEDsAAAAJ
# Fetching author: jJ8BLgsAAAAJ
# Fetching author: mOINlwcAAAAJ
# Fetching author: qnvyqtwAAAAJ
# Fetching author: s-FDyf4AAAAJ

# %%
def scrape_author_profiles_to_csv(professor_ids, csv_file='authors.csv', log_file='processed_authors.txt'):
    field_names = ['Name', 'Affiliation', 'Homepage', 'Email_Domain', 'Scholar_ID', 
        'Interests', 'Citedby', 'Citedby5y', 'hindex', 'hindex5y', 
        'i10index', 'i10index5y']
    # Create CSV file with headers if it doesn't exist
    if not os.path.exists(csv_file):
        with open(csv_file, mode='w', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=field_names)
            writer.writeheader()

    # Load processed IDs to avoid re-processing
    processed_ids = set()
    if os.path.exists(log_file):
        with open(log_file, 'r') as f:
            processed_ids = set(line.strip() for line in f.readlines())

    for prof_id in professor_ids:
        if prof_id in processed_ids:
            print(f"Skipping already processed ID: {prof_id}")
            continue

        try:
            print(f"Fetching author: {prof_id}")
            author = scholarly.search_author_id(prof_id)
            author = scholarly.fill(author, sections=['basics', 'indices', 'counts'])

            author_data = {
                'Name': author.get('name', ''),
                'Affiliation': author.get('affiliation', ''),
                'Homepage': author.get('homepage', ''),
                'Email_Domain': author.get('email_domain', ''),
                'Scholar_ID': prof_id,
                'Interests': ', '.join(author.get('interests', [])),
                'Citedby': author.get('citedby', 0),
                'Citedby5y': author.get('citedby5y', 0),
                'hindex': author.get('hindex', 0),
                'hindex5y': author.get('hindex5y', 0),
                'i10index': author.get('i10index', 0),
                'i10index5y': author.get('i10index5y', 0)
            }

            with open(csv_file, mode='a', newline='', encoding='utf-8') as f:
                writer = csv.DictWriter(f, fieldnames=field_names)
                writer.writerow(author_data)

            # Append processed ID to the log
            with open(log_file, 'a') as log_f:
                log_f.write(f"{prof_id}\n")

        except Exception as e:
            print(f"Error processing author ID {prof_id}: {e}")

# %%
scrape_author_profiles_to_csv(CS_professors2, csv_file='CS_authors.csv')
# Out:
# Fetching author: 22ohn6AAAAAJ
# Fetching author: RxcQjoYAAAAJ
# Fetching author: -6bAV2cAAAAJ
# Fetching author: a_z5a5wAAAAJ
# Fetching author: YfcphqMAAAAJ
# Fetching author: yGtJEDsAAAAJ
# Fetching author: jJ8BLgsAAAAJ
# Fetching author: mOINlwcAAAAJ
# Fetching author: qnvyqtwAAAAJ
# Fetching author: s-FDyf4AAAAJ
