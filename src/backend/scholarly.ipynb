# %%
from scholarly import scholarly
import pandas as pd

# %%
cs_faculty_df = pd.read_csv("./dat/cs_faculty.csv")
qtm_faculty_df = pd.read_csv("./dat/qtm_faculty.csv")

cs_faculty_df
# Out:
#               Professor
# 0      Eugene Agichtein
# 1         Dorian Arnold
# 2         Yana Bromberg
# 3            Jinho Choi
# 4      Nosayba El-Sayed
# 5        Davide Fossati
# 6   Michelangelo Grigni
# 7           Zhichun Guo
# 8              Joyce Ho
# 9               Wei Jin
# 10        Joon-Seok Kim
# 11      Steven La Fleur
# 12              Fei Liu
# 13       Ken Mandelberg
# 14       Yolanda Rankin
# 15              Kai Shu
# 16       Vaidy Sunderam
# 17         Shengpu Tang
# 18           Emily Wall
# 19     Kristin Williams
# 20             Li Xiong
# 21            Carl Yang
# 22           Liang Zhao
# 23        Andreas Zufle

# %%
search_query = scholarly.search_author('Jinho Choi, Emory')
author = scholarly.fill(next(search_query))

print(author)
# Out:
# {'container_type': 'Author', 'filled': ['basics', 'indices', 'counts', 'coauthors', 'publications', 'public_access'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'xdddblAAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=xdddblAAAAAJ', 'name': 'Jinho D. Choi', 'affiliation': 'Associate Professor, Emory University', 'email_domain': '@emory.edu', 'interests': ['Natural Language Processing', 'Computational Linguistics', 'Conversational AI'], 'citedby': 4261, 'organization': 7693822459085397235, 'homepage': 'https://www.emorynlp.org/faculty/jinho-choi', 'citedby5y': 2613, 'hindex': 36, 'hindex5y': 28, 'i10index': 65, 'i10index5y': 50, 'cites_per_year': {2011: 24, 2012: 70, 2013: 97, 2014: 128, 2015: 157, 2016: 231, 2017: 245, 2018: 350, 2019: 309, 2020: 356, 2021: 450, 2022: 537, 2023: 553, 2024: 595, 2025: 116}, 'coauthors': [{'container_type': 'Author', 'filled': [], 'scholar_id': 'pxc_-XYAAAAJ', 'source':
# ...

# %%
print(author.keys())
len(author.keys())
# Out:
# dict_keys(['container_type', 'filled', 'source', 'scholar_id', 'url_picture', 'name', 'affiliation', 'email_domain', 'interests', 'citedby', 'organization', 'homepage', 'citedby5y', 'hindex', 'hindex5y', 'i10index', 'i10index5y', 'cites_per_year', 'coauthors', 'publications', 'public_access'])
# 21

# %%
author_data = {}

for key in author.keys():
    author_data[key] = author[key]

print(author_data)

df_choi = pd.DataFrame.from_dict([author_data])
print(df_choi["publications"])
# Out:
# {'container_type': 'Author', 'filled': ['basics', 'indices', 'counts', 'coauthors', 'publications', 'public_access'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': 'xdddblAAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=xdddblAAAAAJ', 'name': 'Jinho D. Choi', 'affiliation': 'Associate Professor, Emory University', 'email_domain': '@emory.edu', 'interests': ['Natural Language Processing', 'Computational Linguistics', 'Conversational AI'], 'citedby': 4261, 'organization': 7693822459085397235, 'homepage': 'https://www.emorynlp.org/faculty/jinho-choi', 'citedby5y': 2613, 'hindex': 36, 'hindex5y': 28, 'i10index': 65, 'i10index5y': 50, 'cites_per_year': {2011: 24, 2012: 70, 2013: 97, 2014: 128, 2015: 157, 2016: 231, 2017: 245, 2018: 350, 2019: 309, 2020: 356, 2021: 450, 2022: 537, 2023: 553, 2024: 595, 2025: 116}, 'coauthors': [{'container_type': 'Author', 'filled': [], 'scholar_id': 'pxc_-XYAAAAJ', 'source':
# ...
